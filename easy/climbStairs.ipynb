# %%
class Solution:
    def climbStairs(self, n: int) -> int:
        if n == 0 or n == 1:
            return 1
        else:
            return self.climbStairs(n-1) + self.climbStairs(n-2)
        
s = Solution()

print(s.climbStairs( 1))
print(s.climbStairs(2))
print(s.climbStairs(3))
# print(s.climbStairs(3))

print(s.climbStairs(4))
print(s.climbStairs(5))
print(s.climbStairs(6))

print(s.climbStairs(7))
# print(s.climbStairs(44))
# Out:
# 1
# 2
# 3
# 5
# 8
# 13
# 21

# %%
class Solution:
    def climbStairs(self, n: int) -> int:
        befor_num = 0
        final_list = []
        for i in range(1,n+1):
            if i == 1:
                final_list.append(1) 
            if i == 2:
                final_list.append(2)
            elif i > 2: 
                final_list.append(final_list[-1]+final_list[-2]) 
        return final_list[-1]

            
            
        
s = Solution()

print(s.climbStairs( 1))
print(s.climbStairs(2))
print(s.climbStairs(3))
print(s.climbStairs(7))
print(s.climbStairs(44))
# Out:
# 1
# 2
# 3
# 21
# 1134903170
