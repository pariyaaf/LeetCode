# %%
from typing import List

class Solution:
    def longestCommonPrefix(self, strs: List[str]) -> str:
        sorted_words = sorted(strs, key=len)
        shortest_word = sorted_words[0]
        max_prefix = ""
        for i in range(len(shortest_word)):
            prefix = shortest_word[:i+1]

            for word in sorted_words[1:]:
                if prefix != word[:i+1]:
                    return max_prefix
                    
            max_prefix = prefix
        return max_prefix
            
                
            
        


solution = Solution()

print(solution.longestCommonPrefix(["flower","flow","flight"]))  
print(solution.longestCommonPrefix(["dog","racecar","car"]) )
print(solution.longestCommonPrefix(["s","saina",""]) )
print(solution.longestCommonPrefix(["s","saina","saba"]) )
print(solution.longestCommonPrefix(["farhad","farhmand","oodfarh"]) )
print(solution.longestCommonPrefix(["farhad","farhmand","farhood"]) )
# Out:
# fl
#
#
# s
#
# farh
